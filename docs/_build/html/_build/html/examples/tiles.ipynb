# %% [markdown]
# # Tiles

# %%
from supy.tiles import Tiles

# %%
T = Tiles()

# %% [markdown]
# ### Provide the list of ra and dec

# %% [markdown]
# #### Method 1

# %%
ra, dec = 173.6688, -21.05625

T.find_overlapping_tiles(ra=ra, dec=dec, list_aperture = 0,
                         match_tolerance_minutes=4, fraction_overlap_lower= 0.1 )
T.target_table
# Out:
# <Table length=1>
#    ra       dec       hhmmss    ... aperture matched_idx matched_tile
# float64   float64     str12     ...  int64      int64        str6
# -------- --------- ------------ ... -------- ----------- ------------
# 173.6688 -21.05625 11:34:40.512 ...        0           0       T12180

# %% [markdown]
# #### Method 2

# %%
j2000 = 'J110633.45-182124.19'

T.find_overlapping_tiles(j2000=j2000, list_aperture = 0,
                         match_tolerance_minutes=4, fraction_overlap_lower= 0.1 )
T.target_table
# Out:
# <Table length=1>
#         ra                 dec            hhmmss   ... matched_idx matched_tile
#      float64             float64          str11    ...    int64        str6
# ------------------ ------------------- ----------- ... ----------- ------------
# 166.63937499999997 -18.356719444444447 11:06:33.45 ...           0       T12965

# %% [markdown]
# #### Method 3

# %%
loc = [173.6688, -21.05625]

T.find_overlapping_tiles(loc=loc, list_aperture = 0,
                         match_tolerance_minutes=4, fraction_overlap_lower= 0.1 )
T.target_table
# Out:
# <Table length=1>
#    ra       dec       hhmmss    ... aperture matched_idx matched_tile
# float64   float64     str12     ...  int64      int64        str6
# -------- --------- ------------ ... -------- ----------- ------------
# 173.6688 -21.05625 11:34:40.512 ...        0           0       T12180

# %% [markdown]
# ### List of localizations

# %%
loc = [[173.6688, -21.05625], 'J110633.45-182124.19']

T.find_overlapping_tiles(loc=loc, 
                         match_tolerance_minutes=4, fraction_overlap_lower= 0.1 )
T.target_table
# Out:
# <Table length=2>
#         ra                 dec         ... matched_idx matched_tile
#      float64             float64       ...    int64        str6
# ------------------ ------------------- ... ----------- ------------
#           173.6688           -21.05625 ...           0       T12180
# 166.63937499999997 -18.356719444444447 ...           1       T12965

# %% [markdown]
# ### Matched tile information

# %%
T.tile_table
# Out:
# <Table length=2>
#   id           ra         ... overlapped_area is_within_boundary
#  str6       float64       ...      int64             bool
# ------ ------------------ ... --------------- ------------------
# T12180 173.79310344827587 ...               1               True
# T12965 166.46616541353384 ...               1               True

# %% [markdown]
# ### Visualize the tiles

# %%
T.visualize_tiles()
